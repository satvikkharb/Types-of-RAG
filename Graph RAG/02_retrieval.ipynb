# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_neo4j import Neo4jGraph, GraphCypherQAChain
from langchain_core.prompts import PromptTemplate

# %%
load_dotenv()
# Out:
# True

# %%
# temperature=0 keeps Cypher generation deterministic
llm = ChatOpenAI(model="gpt-5-mini", temperature=0)

# %%
graph = Neo4jGraph(
    url=os.environ["NEO4J_URI"],
    username=os.environ["NEO4J_USERNAME"],
    password=os.environ["NEO4J_PASSWORD"],
)
# refresh_schema gives the chain an accurate view of node labels and relationship types
graph.refresh_schema()
print(graph.schema)
# This is the schema that is viewed by the LLM when generating Cypher queries. It is important to keep this up to date with the actual graph database schema.
# Out:
# Node properties:
# Document {id: STRING, text: STRING, creator: STRING, creationdate: STRING, keywords: STRING, trapped: STRING, author: STRING, subject: STRING, source: STRING, total_pages: INTEGER, title: STRING, moddate: STRING, producer: STRING, page: INTEGER, page_label: STRING, embedding: LIST}
# Person {id: STRING}
# Date {id: STRING}
# Place {id: STRING}
# Nationality {id: STRING}
# Occupation {id: STRING}
# Recognition {id: STRING}
# Location {id: STRING}
# Company {id: STRING}
# Organization {id: STRING}
# Software {id: STRING}
# Money {id: STRING}
# Year {id: STRING}
# Goal {id: STRING}
# Product {id: STRING}
# Service {id: STRING}
# Concept {id: STRING}
# Activity {id: STRING}
# Thing {id: STRING}
# Relationship properties:
#
# The relationships:
# (:Document)-[:MENTIONS]->(:Person)
# (:Document)-[:MENTIONS]->(:Date)
# (:Document)-[:MENTIONS]->(:Place)
# (:Document)-[:MENTIONS]->(:Nationality)
# (:Document)-[:MENTIONS]->(:Occupation)
# (:Document)-[:MENTIONS]->(:Recognition)
# (:Document)-[:MENTIONS]->(:Location)
# (:Document)-[:MENTIONS]->(:Company)
# (:Document)-[:MENTIONS]->(:Organization)
# (:Document)-[:MENTIONS]->(:Software)
# (:Document)-[:MENTIONS]->(:Money)
# (:Document)-[:MENTIONS]->(:Year)
# (:Document)-[:MENTIONS]->(:Goal)
# (:Document)-[:MENTIONS]->(:Product)
# (:Document)-[:MENTIONS]->(:Service)
# (:Document)-[:MENTIONS]->(:Concept)
# (:Document)-[:MENTIONS]->(:Activity)
# (:Document)-[:MENTIONS]->(:Thing)
# (:Person)-[:BIRTH_DATE]->(:Date)
# (:Person)-[:BIRTHPLACE]->(:Place)
# (:Person)-[:NATIONALITY]->(:Nationality)
# (:Person)-[:NATIONALITY]->(:Location)
# (:Person)-[:OCCUPATION]->(:Occupation)
# (:Person)-[:RECOGNISED_AS]->(:Recognition)
# (:Person)-[:SPOUSE]->(:Person)
# (:Person)-[:PARENT]->(:Person)
# (:Person)-[:PARTNER]->(:Person)
# (:Person)-[:CO_FOUNDER]->(:Organization)
# (:Person)-[:ACQUIRED]->(:Organization)
# (:Person)-[:FOUNDER]->(:Organization)
# (:Person)-[:CEO]->(:Company)
# (:Person)-[:CEO]->(:Organization)
# (:Person)-[:CHIEF_ENGINEER]->(:Organization)
# (:Person)-[:SINCE]->(:Date)
# (:Person)-[:FOUNDED]->(:Organization)
# (:Person)-[:LEFT_BOARD]->(:Organization)
# (:Person)-[:LEFT_BOARD_IN]->(:Date)
# (:Person)-[:COFOUNDER]->(:Company)
# (:Person)-[:COFOUNDER]->(:Organization)
# (:Person)-[:FATHER]->(:Person)
# (:Person)-[:MOTHER]->(:Person)
# (:Person)-[:BROTHER]->(:Person)
# (:Person)-[:SISTER]->(:Person)
# (:Person)-[:BASED_IN]->(:Location)
# (:Person)-[:SAME_AS]->(:Person)
# (:Person)-[:DIRECTOR]->(:Company)
# (:Person)-[:DIRECTOR]->(:Organization)
# (:Person)-[:BORN_IN]->(:Date)
# (:Place)-[:PART_OF]->(:Place)
# (:Place)-[:PART_OF]->(:Location)
# (:Place)-[:LOCATED_IN]->(:Place)
# (:Place)-[:LOCATED_IN]->(:Location)
# (:Location)-[:PART_OF]->(:Place)
# (:Location)-[:PART_OF]->(:Location)
# (:Location)-[:LOCATED_IN]->(:Place)
# (:Location)-[:LOCATED_IN]->(:Location)
# (:Company)-[:HEADQUARTERED_IN]->(:Location)
# (:Company)-[:FOUNDED_IN]->(:Date)
# (:Company)-[:FOUNDED_IN]->(:Year)
# (:Company)-[:DEVELOPS]->(:Concept)
# (:Organization)-[:HEADQUARTERED_IN]->(:Location)
# (:Organization)-[:HEADQUARTERED_IN]->(:Place)
# (:Organization)-[:FOUNDED_IN]->(:Date)
# (:Organization)-[:FOUNDED_IN]->(:Year)
# (:Organization)-[:DEVELOPS]->(:Concept)
# (:Organization)-[:DEVELOPED]->(:Software)
# (:Organization)-[:ACQUIRED]->(:Organization)
# (:Organization)-[:ACQUIRED_IN]->(:Date)
# (:Organization)-[:ACQUIRED_IN]->(:Year)
# (:Organization)-[:ACQUISITION_AMOUNT]->(:Money)
# (:Organization)-[:GOAL]->(:Goal)
# (:Organization)-[:MANUFACTURES]->(:Product)
# (:Organization)-[:CO_FOUNDED_BY]->(:Person)
# (:Organization)-[:FOUNDED_BY]->(:Person)
# (:Organization)-[:PROVIDES]->(:Service)
# (:Organization)-[:CONDUCTS_RESEARCH]->(:Concept)
# (:Organization)-[:RELEASED]->(:Product)
# (:Organization)-[:CONDUCTS]->(:Activity)
# (:Organization)-[:CREATED]->(:Product)
# (:Organization)-[:OWNED_BY]->(:Person)
# (:Organization)-[:IS_A]->(:Concept)
# (:Organization)-[:CONSTRUCTS]->(:Thing)
# (:Goal)-[:TARGET]->(:Location)
# (:Product)-[:RELEASED_IN]->(:Date)

# %%
# Neo4J 5+ requires [:TYPE1|TYPE2|TYPE3] — no colon before subsequent types in a union.
# LLMGraphTransformer title-cases node ids (e.g. "SpaceX" -> "Spacex"), so queries
# must use toLower() to avoid case-mismatch misses.
_CYPHER_TEMPLATE = """Task: Generate a Cypher statement to query a graph database.
Instructions:
Use only the provided relationship types and properties in the schema.
Do not use any other relationship types or node labels that are not provided.
Schema:
{schema}

Cypher syntax rules:
1. When matching multiple relationship types with |, only the FIRST type gets a colon prefix:
   Correct:   (n)-[:TYPE1|TYPE2|TYPE3]->(m)
   Incorrect: (n)-[:TYPE1|:TYPE2|:TYPE3]->(m)

2. When a node could have one of several labels, use label union syntax directly in the MATCH clause:
   Correct:   MATCH (n:Organization|Company)
   Incorrect: WHERE (n:`Organization OR n`:Company)

3. Organization and place names are stored with title-cased words. Always compare case-insensitively:
   Correct:   WHERE toLower(n.id) = toLower("SpaceX")
   Incorrect: WHERE n.id = "SpaceX"

4. Person names may be stored in abbreviated or partial forms (e.g. "Musk" instead of "Elon Musk").
   Always match person names with CONTAINS rather than exact equality:
   Correct:   WHERE toLower(p.id) CONTAINS 'elon' AND toLower(p.id) CONTAINS 'musk'
   Incorrect: WHERE toLower(p.id) = toLower("Elon Musk")

Note: Do not include any explanations or apologies in your responses.
Do not respond to any questions that might ask anything else than for you to construct a Cypher statement.
Do not include any text except the generated Cypher statement.

The question is:
{question}"""

_cypher_prompt = PromptTemplate(
    input_variables=["schema", "question"],
    template=_CYPHER_TEMPLATE,
)

# verbose=True prints the generated Cypher so students can see the traversal path
# allow_dangerous_requests is required in langchain-neo4j >= 0.1
cypher_chain = GraphCypherQAChain.from_llm(
    llm=llm,
    graph=graph,
    verbose=True,
    allow_dangerous_requests=True,
    cypher_prompt=_cypher_prompt,
)

# %%
# single-hop — one relationship traversal
response = cypher_chain.invoke({"query": "Where is Spacex HQ located?"})
print(response["result"])
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (e:Organization|Company)
# WHERE toLower(e.id) = toLower("SpaceX")
# OPTIONAL MATCH (e)-[:HEADQUARTERED_IN]->(loc:Location)
# OPTIONAL MATCH (e)-[:HEADQUARTERED_IN]->(pl:Place)
# RETURN DISTINCT coalesce(loc.id, pl.id) AS headquarters, loc, pl;
# Full Context:
# [{'headquarters': 'Hawthorne, California, United States', 'loc': {'id': 'Hawthorne, California, United States'}, 'pl': None}]
#
# > Finished chain.
# Spacex HQ is located in Hawthorne, California, United States.

# %%
# each question requires chaining 2+ relationships — this is what Graph RAG excels at
multi_hop_queries = [
    "What product was released by the organisation whose board Elon Musk left?",
    "At which organisation is Elon Musk's partner Shivon Zilis a director?",
    "In which city is the solar energy company that Tesla acquired headquartered?",
]

for q in multi_hop_queries:
    print(f"\nQ: {q}")
    response = cypher_chain.invoke({"query": q})
    print(f"A: {response['result']}")
    print("-" * 60)
# Out:
# Q: What product was released by the organisation whose board Elon Musk left?
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p:Person)-[:LEFT_BOARD]->(org:Organization)-[:RELEASED]->(product:Product)
# WHERE toLower(p.id) CONTAINS 'elon' AND toLower(p.id) CONTAINS 'musk'
# RETURN DISTINCT product.id
# Full Context:
# [{'product.id': 'Chatgpt'}]
#
# > Finished chain.
# A: Chatgpt was released by the organisation whose board Elon Musk left.
# ------------------------------------------------------------
#
# Q: At which organisation is Elon Musk's partner Shivon Zilis a director?
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (elon:Person), (shiv:Person)-[:DIRECTOR]->(org:Organization|Company)
# MATCH (elon)-[:PARTNER]-(shiv)
# WHERE toLower(elon.id) CONTAINS 'elon' AND toLower(elon.id) CONTAINS 'musk'
#   AND toLower(shiv.id) CONTAINS 'shivon' AND toLower(shiv.id) CONTAINS 'zilis'
# RETURN DISTINCT org.id
# Full Context:
# [{'org.id': 'Neuralink'}]
#
# > Finished chain.
# A: Shivon Zilis is a director at Neuralink.
# ------------------------------------------------------------
#
# Q: In which city is the solar energy company that Tesla acquired headquartered?
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (t:Organization|Company)-[:ACQUIRED]->(co:Organization)
# OPTIONAL MATCH (co)-[:IS_A]->(c:Concept)
# MATCH (co)-[:HEADQUARTERED_IN]->(loc:Location|Place)
# WHERE toLower(t.id) = toLower("Tesla")
#   AND (toLower(co.id) CONTAINS 'solar' OR (c IS NOT NULL AND toLower(c.id) CONTAINS 'solar'))
# RETURN DISTINCT loc.id;
# Full Context:
# [{'loc.id': 'San Mateo, California, United States'}]
#
# > Finished chain.
# A: The solar energy company is headquartered in San Mateo, California, United States.
# ------------------------------------------------------------
